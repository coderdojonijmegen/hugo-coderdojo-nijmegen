# %% [markdown]
# # Init
# Get the data from the EventBrite API and process it into a list of events.
# Cache it to an `events.json` file stored in the file system.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv

from bezoekers_analyse import Events

load_dotenv()

api_key = os.getenv("VAR_EVENTBRITE_API_KEY")
plt.close("all")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

events = Events(
    # documentation: https://www.eventbrite.nl/platform/api
    # new API key from: https://www.eventbrite.nl/platform/api-keys/
    #   note: each visit of this page creates a new API key at https://www.eventbrite.nl/account-settings/apps
    # API key stored in Bitwarden vault Bas
    api_key,
    [
        "zwanenveld",
        "biezantijn",
        "mariënburg",
        "online",
        "valkhof",
    ],
    [
        37396107765,
        43018135401,
        49624002728,
    ]
)

# %% [markdown]
# # List all dojo's over time

# %%
columns, dojos = events.get_dojos()
pd.DataFrame(dojos, columns=columns)
# Out:
#     maand       datum                                              locatie  \
# 0      11  2016-11-05                            Bibliotheek De Mariënburg
# 1      12  2016-12-03                               Bibliotheek Zwanenveld
# 2      01  2017-01-07                                        De Biezantijn
# 3      02  2017-02-04                                        De Biezantijn
# 4      03  2017-03-04                                        De Biezantijn
# 5      04  2017-04-01                                        De Mariënburg
# 6      05  2017-05-06                                        De Mariënburg
# 7      06  2017-06-03                                        De Mariënburg
# 8      07  2017-07-01                            Bibliotheek De Biezantijn
# 9      08  2017-08-05                                        De Smeltkroes
# 10     09  2017-09-02                                      Het Cultuurcafé
# 11     10  2017-10-07                                        De Biezantijn
# 12     11  2017-11-04                            Bibliotheek De Mariënburg
# 13     12  2017-12-02                               Bibliotheek Zwanenveld
# 14     01  2018-01-06                            Bibliotheek De Mariënburg
# 15     02  2018-02-03                                         AT Computing
# 16     03  2018-03-03                                   Museum het Valkhof
# 17     04  2018-04-07                            Bibliotheek De Biezantijn
# 18     05  2018-05-05                            Bibliotheek De Mariënburg
# 19     06  2018-06-02                               Bibliotheek Zwanenveld
# 20     07  2018-07-07                                        De Biezantijn
# 21     08  2018-08-04                                        De Mariënburg
# 22     09  2018-09-01                                  Elinor Ostromgebouw
# 23     10  2018-10-06                                        De Biezantijn
# 24     11  2018-11-03                                         Isatis Group
# 25     12  2018-12-01                               Bibliotheek Zwanenveld
# 26     01  2019-01-05                                 Hackerspace Nijmegen
# 27     02  2019-02-02                            Bibliotheek De Mariënburg
# 28     03  2019-03-02                                              Rootnet
# 29     04  2019-04-06                                        De Biezantijn
# 30     05  2019-05-04                               Bibliotheek Zwanenveld
# 31     06  2019-06-01                            Bibliotheek De Mariënburg
# 32     07  2019-07-06                            Bibliotheek De Mariënburg
# 33     08  2019-08-03                            Bibliotheek De Mariënburg
# 34     09  2019-09-07                            Bibliotheek De Mariënburg
# 35     10  2019-10-05                                        De Biezantijn
# 36     11  2019-11-02                               Bibliotheek Zwanenveld
# 37     12  2019-12-07                                        De Biezantijn
# 38     01  2020-01-11                                 Hackerspace Nijmegen
# 39     02  2020-02-01                            Bibliotheek De Mariënburg
# 40     03  2020-03-07                                              Rootnet
# 41     04  2020-04-04                                               online
# 42     05  2020-05-02                                               online
# 43     06  2020-06-06                                               online
# 44     07  2020-07-04                                               online
# 45     08  2020-08-15                                        De Smeltkroes
# 46     09  2020-09-05                                        De Smeltkroes
# 47     10  2020-10-10                                               online
# 48     11  2020-11-07                                               online
# 49     12  2020-12-12                                               online
# 50     01  2021-01-09                                               online
# 51     02  2021-02-06                                               online
# 52     03  2021-03-06                                               online
# 53     04  2021-04-03                                               online
# 54     05  2021-05-01                                               online
# 55     06  2021-06-05                                               online
# 56     07  2021-07-03                                        De Smeltkroes
# 57     08  2021-08-07                                        De Smeltkroes
# 58     09  2021-09-04                                        De Smeltkroes
# 59     10  2021-10-02                               Bibliotheek Zwanenveld
# 60     11  2021-11-06                               Bibliotheek Zwanenveld
# 61     12  2021-12-11                                               online
# 62     05  2022-05-07                               Bibliotheek Zwanenveld
# 63     06  2022-06-04                                   Museum Het Valkhof
# 64     07  2022-07-02                               Bibliotheek Zwanenveld
# 65     08  2022-08-06                               Bibliotheek Zwanenveld
# 66     09  2022-09-03                                        De Biezantijn
# 67     10  2022-10-01                               Bibliotheek Zwanenveld
# 68     11  2022-11-05                               Bibliotheek Zwanenveld
# 69     12  2022-12-10                            Bibliotheek de Biezantijn
# 70     01  2023-01-14                   computer museum @ Mosadex e-health
# 71     02  2023-02-04                               Bibliotheek Zwanenveld
# 72     03  2023-03-04                            Bibliotheek de Biezantijn
# 73     04  2023-04-01                          De Klinker - de Grote Broek
# 74     05  2023-05-06                               Bibliotheek Zwanenveld
# 75     06  2023-06-03                            Bibliotheek de Biezantijn
# 76     07  2023-07-01                                  Bibliotheek Muntweg
# 77     09  2023-09-02                           Bibliotheek Lent - De Ster
# 78     10  2023-10-07                   computer museum @ Mosadex e-health
# 79     11  2023-11-04                               Bibliotheek Zwanenveld
# 80     12  2023-12-09                                  Bibliotheek Muntweg
# 81     01  2024-01-13  Library Gelderland Zuid / Library Marienburg (OBGZ)
# 82     02  2024-02-03                          De Achtertuin (in de Vasim)
# 83     03  2024-03-02                               Bibliotheek Zwanenveld
# 84     04  2024-04-06  Library Gelderland Zuid / Library Marienburg (OBGZ)
# 85     05  2024-05-11                   computer museum @ Mosadex e-health
# 86     06  2024-06-01                               Bibliotheek Zwanenveld
# 87     07  2024-07-06                                  Bibliotheek Muntweg
# 88     09  2024-09-07                                         Rootnet B.V.
# 89     10  2024-10-05                               Bibliotheek Zwanenveld
# 90     11  2024-11-02                   computer museum @ Mosadex e-health
# 91     12  2024-12-14  Library Gelderland Zuid / Library Marienburg (OBGZ)
# 92     01  2025-01-11                               Bibliotheek Zwanenveld
# 93     02  2025-02-01                                         Rootnet B.V.
# 94     03  2025-03-08                                  Bibliotheek Muntweg
# 95     04  2025-04-05                   computer museum @ Mosadex e-health
# 96     05  2025-05-10                               Bibliotheek Zwanenveld
# 97     06  2025-06-07  Library Gelderland Zuid / Library Marienburg (OBGZ)
# 98     07  2025-07-05                                  Bibliotheek Muntweg
# 99     09  2025-09-06                               Bibliotheek Zwanenveld
# 100    10  2025-10-04                                         Rootnet B.V.
# 101    11  2025-11-01                                  Bibliotheek Muntweg
# 102    12  2025-12-13                   computer museum @ Mosadex e-health
# 103    01  2026-01-10  Library Gelderland Zuid / Library Marienburg (OBGZ)
# 104    02  2026-02-07                               Bibliotheek Zwanenveld
# 105    03  2026-03-07                                         Rootnet B.V.
# 106    04  2026-04-04                                  Bibliotheek Muntweg
# 107    05  2026-05-09  Library Gelderland Zuid / Library Marienburg (OBGZ)
# 108    06  2026-06-06                   computer museum @ Mosadex e-health
# 109    07  2026-07-04                               Bibliotheek Zwanenveld
#
#                                                               onderwerp  \
# 0                                                CoderDojo Nijmegen #22
# 1                                                CoderDojo Nijmegen #23
# 2                                                CoderDojo Nijmegen #24
# 3                                                CoderDojo Nijmegen #25
# 4                                                CoderDojo Nijmegen #26
# 5                                                CoderDojo Nijmegen #27
# 6                                                CoderDojo Nijmegen #28
# 7                                                CoderDojo Nijmegen #29
# 8                                                         CoderDojo #30
# 9                                                         CoderDojo #31
# 10                                                        CoderDojo #32
# 11                                                        CoderDojo #33
# 12                                               CoderDojo Nijmegen #34
# 13                                               CoderDojo Nijmegen #35
# 14                                               CoderDojo Nijmegen #36
# 15                                               CoderDojo Nijmegen #37
# 16                                               CoderDojo Nijmegen #38
# 17                                               CoderDojo Nijmegen #39
# 18                                               CoderDojo Nijmegen #40
# 19                                               CoderDojo Nijmegen #41
# 20                                               CoderDojo Nijmegen #42
# 21                                               CoderDojo Nijmegen #43
# 22                                               CoderDojo Nijmegen #44
# 23                                               CoderDojo Nijmegen #45
# 24                                               CoderDojo Nijmegen #46
# 25                                               CoderDojo Nijmegen #47
# 26                                               CoderDojo Nijmegen #48
# 27                                               CoderDojo Nijmegen #49
# 28                                               CoderDojo Nijmegen #50
# 29                                               CoderDojo Nijmegen #51
# 30                                               CoderDojo Nijmegen #52
# 31                                               CoderDojo Nijmegen #53
# 32                                               CoderDojo Nijmegen #54
# 33                                               CoderDojo Nijmegen #55
# 34                                               CoderDojo Nijmegen #56
# 35                                               CoderDojo Nijmegen #57
# 36                                               CoderDojo Nijmegen #58
# 37                                               CoderDojo Nijmegen #59
# 38                                               CoderDojo Nijmegen #60
# 39                                               CoderDojo Nijmegen #61
# 40                                               CoderDojo Nijmegen #62
# 41         CoderDojo Nijmegen #63 online: Scratch, Python of Processing
# 42                     CoderDojo Nijmegen #64 online: Scratch en Python
# 43                       CoderDojo Nijmegen #65 online: Scratch en LÖVE
# 44                     CoderDojo Nijmegen #66 online: Scratch en Python
# 45                                     CoderDojo Nijmegen #67 Unplugged
# 46                                        CoderDojo Nijmegen #68 Robots
# 47    CoderDojo Nijmegen #69 online: Scratch, Python en MakeCode Arcade
# 48                        CoderDojo Nijmegen #70 online: Websites maken
# 49                              CoderDojo Nijmegen #71 online: Sonic Pi
# 50               CoderDojo Nijmegen #72 online: Kies je eigen onderwerp
# 51               CoderDojo Nijmegen #73 online: Kies je eigen onderwerp
# 52                        CoderDojo Nijmegen #74 online: Websites maken
# 53                      CoderDojo Nijmegen #75 online: Machine Learning
# 54               CoderDojo Nijmegen #76 online: Kies je eigen onderwerp
# 55               CoderDojo Nijmegen #77 online: bouw je eigen chat app!
# 56                                 CoderDojo Nijmegen #78 LIVE: Arduino
# 57                                     CoderDojo Nijmegen #79 Unplugged
# 58                        CoderDojo Nijmegen #80: Unplugged + micro:bit
# 59                          CoderDojo Nijmegen #81: Python (en Scratch)
# 60          CoderDojo Nijmegen #82: Kunst, met Scratch, Python en p5.js
# 61              CoderDojo Nijmegen #83 online: Kunst en games met P5.js
# 62                                    CoderDojo Nijmegen #84: micro:bit
# 63          CoderDojo Nijmegen #85: Kunst, met Scratch, Python en p5.js
# 64                      CoderDojo Nijmegen #86: Kies je eigen onderwerp
# 65                               CoderDojo Nijmegen #87: Websites maken
# 66                             CoderDojo Nijmegen #88: Machine Learning
# 67                CoderDojo Nijmegen #89: Ontbijtkoek Clicker & Arduino
# 68      CoderDojo Nijmegen #90: Webpagina's maken & Ontbijtkoek Clicker
# 69                          CoderDojo Nijmegen #91: Python (en Scratch)
# 70                   CoderDojo Nijmegen #92: Raspberry Pi  &  micro:bit
# 71                       CoderDojo Nijmegen #93: Games maken met Löve2D
# 72                                   CoderDojo Nijmegen #94: Processing
# 73                             CoderDojo Nijmegen #95: Machine Learning
# 74                                   CoderDojo Nijmegen #96: Ninja Chat
# 75                      CoderDojo Nijmegen #97: Kies je eigen onderwerp
# 76                      CoderDojo Nijmegen #98: Kies je eigen onderwerp
# 77                                     CoderDojo Nijmegen #99 Unplugged
# 78                                  CoderDojo Nijmegen #100: Processing
# 79                     CoderDojo Nijmegen #101: Kies je eigen onderwerp
# 80                           CoderDojo Nijmegen #102: code.org & Python
# 81                  CoderDojo Nijmegen #103: Raspberry Pi Pico + Thonny
# 82                                 CoderDojo Nijmegen #104: Chat webapp
# 83            CoderDojo Nijmegen #105: muziek programmeren met Sonic Pi
# 84                      CoderDojo Nijmegen #106: games maken met Löve2D
# 85   CoderDojo Nijmegen #107: kunst maken, met Scratch, Python en p5.js
# 86                                    CoderDojo Nijmegen #108: Scratch!
# 87                                        CoderDojo Nijmegen #109: Hedy
# 88                                  CoderDojo Nijmegen #110: HTML & CSS
# 89                        CoderDojo Nijmegen #111: Streepjescodes maken
# 90                    CoderDojo Nijmegen #112: Raspberry Pi & Micro:bit
# 91       CoderDojo Nijmegen #113: Kerstbomen en sneeuwvlokken met p5.js
# 92                         CoderDojo Nijmegen #114: vuurwerk met Python
# 93                    CoderDojo Nijmegen #115: Code.org & Java workshop
# 94                   CoderDojo Nijmegen #116: Hacken - Capture the Flag
# 95           CoderDojo Nijmegen #117: Linux commandline op Raspberry Pi
# 96                         CoderDojo Nijmegen #118: je mag zelf kiezen!
# 97                           CoderDojo Nijmegen #119: Ninja Chat webapp
# 98                         CoderDojo Nijmegen #120: je mag zelf kiezen!
# 99                                        CoderDojo Nijmegen #121: dojo
# 100                                       CoderDojo Nijmegen #122: dojo
# 101                                       CoderDojo Nijmegen #123: dojo
# 102                                       CoderDojo Nijmegen #124: dojo
# 103                                       CoderDojo Nijmegen #125: dojo
# 104                                       CoderDojo Nijmegen #126: dojo
# 105                                       CoderDojo Nijmegen #127: dojo
# 106                                       CoderDojo Nijmegen #128: dojo
# 107                                       CoderDojo Nijmegen #129: dojo
# 108                                       CoderDojo Nijmegen #130: dojo
# 109                                       CoderDojo Nijmegen #131: dojo
#
#      aantal tickets  gekocht  ingecheckt
# 0                25       28          20
# 1                18       19          12
# 2                20       14          12
# 3                20       16          10
# 4                20       13          13
# 5                20       12          10
# 6                20       17          11
# 7                16       16          11
# 8                18       10           8
# 9                20        9           7
# 10               20       13          12
# 11               20       20          18
# 12               20       16          10
# 13               20       16          10
# 14               20       15          11
# 15               16       19          16
# 16               22       24          20
# 17               18       20          11
# 18               15       11           9
# 19               20        8           8
# 20               20       14          12
# 21               20       11          10
# 22               18       16          15
# 23               20       22          19
# 24               30       22          16
# 25               20       12           8
# 26               15       15          15
# 27               21       26          14
# 28               15       13          11
# 29               20       21          15
# 30               20       17          11
# 31               20       16          12
# 32               20       18          13
# 33               12       11          10
# 34               20       19          17
# 35               20       16          15
# 36               18       18          10
# 37               22       22          19
# 38               17       18          16
# 39               25       21          17
# 40               25       29          14
# 41               30       35          26
# 42               20       22          17
# 43               20       14          11
# 44               22       23          15
# 45               20        8           4
# 46               10       14           9
# 47               20       16          11
# 48               20       22           9
# 49               20       16           5
# 50               15       15          10
# 51               20       11           8
# 52               15       14           9
# 53               15       15           9
# 54               20        6           3
# 55               10        7           5
# 56               15       15           8
# 57                3        4           0
# 58               15        5           3
# 59               15       12           7
# 60               15       11           8
# 61               15        6           3
# 62               15       15          10
# 63               19       19          15
# 64               15       13          11
# 65               15        7           6
# 66               20       13          10
# 67               15        4           0
# 68               15       12          10
# 69               20        7           6
# 70               20       20          16
# 71               15        8           6
# 72               20       10           8
# 73               11        7           7
# 74               15        1           0
# 75               20       10           7
# 76                6        7           6
# 77               10        9           6
# 78               20       15          14
# 79               15        5           5
# 80               15       13          10
# 81               15       10           9
# 82               15        8           7
# 83               15       12          11
# 84               15       14          14
# 85               20        9           7
# 86               15        7           7
# 87               15       15          11
# 88               15       15           9
# 89               15        8           5
# 90               20       18          13
# 91               18       17          13
# 92               15       14          12
# 93               15       12          10
# 94               15       19          13
# 95               20       13           9
# 96               15       15          11
# 97               15       16          11
# 98               15       15          14
# 99               15        0           0
# 100              15        0           0
# 101              15        0           0
# 102              15        0           0
# 103              15        0           0
# 104              15        0           0
# 105              15        0           0
# 106              15        0           0
# 107              15        0           0
# 108              15        0           0
# 109              15        0           0

# %% [markdown]
# # Available, booked and checked-in

# %%
axes, stats = events.get_dojo_stats()
df = pd.DataFrame(stats)
df.plot(x=axes['x'], y=axes['y'], kind='bar', stacked=True, figsize=(20,8), width=0.8, title='dojo stats')
# Out:
# <Axes: title={'center': 'dojo stats'}, xlabel='datum'>

# %% [markdown]
# # Show checkins over time

# %%
axes, checkins = events.get_checkins_over_time()
df = pd.DataFrame(checkins)
df.plot(x=axes['x'], y=axes['y'], kind='bar', stacked=True, width=0.8, figsize=(20,8), colormap='jet', title='checkins over tijd')
# Out:
# <Axes: title={'center': 'checkins over tijd'}, xlabel='datum'>

# %% [markdown]
# # Show checkins over time per location

# %%
locations, checkins = events.get_checkins_per_location_over_time()
df = pd.DataFrame(checkins)
df.plot(x='datum', y=locations, kind='bar', figsize=(20,8), stacked=True, width=0.8, colormap='hsv', title='checkins over tijd per locatie')
# Out:
# <Axes: title={'center': 'checkins over tijd per locatie'}, xlabel='datum'>

# %% [markdown]
# # Show checkins over time month of the year

# %%
columns, axes, monthly = events.get_checkins_per_month_of_the_year()
df = pd.DataFrame(monthly, columns=columns)
df.plot(x=axes['x'], y=axes['y'], kind='bar', title='checkins per maand van het jaar')
# Out:
# <Axes: title={'center': 'checkins per maand van het jaar'}, xlabel='maand'>
